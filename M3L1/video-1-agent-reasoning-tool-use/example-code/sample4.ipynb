# %% [markdown]
# Video 1: Razonamiento de Agentes y Uso de Herramientas — De Pipelines de LLM a Agentes

# %%
# Uso de Herramientas

# %%
import time

print("=== Uso de Herramientas en Agentes ===")
print("Los agentes llaman herramientas externas para ampliar sus capacidades: calculadoras, APIs, bases de datos y más.")
time.sleep(0.6)
print("En esta demo usaremos una función de calculadora simple para garantizar aritmética precisa.")
print("=== Visual ASCII: Cinturón de Herramientas ===")
print("""
Cinturón de herramientas del Agente:
[1] calculator(expr) -> aritmética exacta
[2] http_get(url) -> llamadas a APIs (ejemplo)
[3] db_query(sql) -> bases de datos (ejemplo)
[4] file_read(path) -> archivos locales (ejemplo)
Patrón de uso: Pensamiento -> elegir herramienta -> Acción -> Observación -> actualizar Pensamiento
""")
time.sleep(1.0)
# Out:
# === Uso de Herramientas en Agentes ===
# Los agentes llaman herramientas externas para ampliar sus capacidades: calculadoras, APIs, bases de datos y más.
# En esta demo usaremos una función de calculadora simple para garantizar aritmética precisa.
# === Visual ASCII: Cinturón de Herramientas ===
#
# Cinturón de herramientas del Agente:
# [1] calculator(expr) -> aritmética exacta
# [2] http_get(url) -> llamadas a APIs (ejemplo)
# [3] db_query(sql) -> bases de datos (ejemplo)
# [4] file_read(path) -> archivos locales (ejemplo)
# Patrón de uso: Pensamiento -> elegir herramienta -> Acción -> Observación -> actualizar Pensamiento
