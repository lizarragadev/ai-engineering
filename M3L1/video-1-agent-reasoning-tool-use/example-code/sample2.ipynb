# %%
# Video 1: Razonamiento de Agentes y Uso de Herramientas — De Pipelines de LLM a Agentes

# %%
# Distinción Conceptual

# %%
import time

print("¿Qué es un Agente de IA? A diferencia de un pipeline tradicional de LLM, un agente razona, planifica y actúa.")
time.sleep(0.6)
print("[Diagrama] Ruta A: Prompt -> Respuesta Única (pipeline estático)")
print("[Diagrama] Ruta B: Objetivo -> Pensamiento -> Acción (Herramienta) -> Observación -> Repetir -> Respuesta Final (agente)")
# --- Visualización ASCII ---
print("""
+--------------------+     +------------------+
| Pipeline           |     | Agente           |
|--------------------|     |------------------|
| Prompt -> Respuesta|     | Objetivo         |
| (una sola vez)     |     | VS. ↓            |
|                    |     | Pensamiento -> Acción
|                    |     | -> Observación   |
|                    |     | (bucle)          |
+--------------------+     +------------------+
""")
time.sleep(1.2)
# Out:
# ¿Qué es un Agente de IA? A diferencia de un pipeline tradicional de LLM, un agente razona, planifica y actúa.
# [Diagrama] Ruta A: Prompt -> Respuesta Única (pipeline estático)
# [Diagrama] Ruta B: Objetivo -> Pensamiento -> Acción (Herramienta) -> Observación -> Repetir -> Respuesta Final (agente)
#
# +--------------------+     +------------------+
# | Pipeline           |     | Agente           |
# |--------------------|     |------------------|
# | Prompt -> Respuesta|     | Objetivo         |
# | (una sola vez)     |     | VS. ↓            |
# |                    |     | Pensamiento -> Acción
# |                    |     | -> Observación   |
# |                    |     | (bucle)          |
# +--------------------+     +------------------+
