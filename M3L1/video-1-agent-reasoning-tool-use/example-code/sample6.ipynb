# %%
# Video 1: Razonamiento de Agentes y Uso de Herramientas — De Pipelines de LLM a Agentes

# %%
# Recap

# %%
import time

print("=== Resumen y Transición ===")
print("Hoy contrastamos pipelines estáticos vs. agentes con razonamiento y uso de herramientas.")
time.sleep(0.6)
print("A continuación: el framework ReAct para formalizar el ciclo Pensar-Actuar-Observar.")
print("Visual ASCII: Bucle ReAct")
print("Pensamiento -> Acción(herramienta) -> Observación -> (repetir) -> Respuesta Final")
time.sleep(0.8)
print("[Fin de la Demo]")
# Out:
# === Resumen y Transición ===
# Hoy contrastamos pipelines estáticos vs. agentes con razonamiento y uso de herramientas.
# A continuación: el framework ReAct para formalizar el ciclo Pensar-Actuar-Observar.
# Visual ASCII: Bucle ReAct
# Pensamiento -> Acción(herramienta) -> Observación -> (repetir) -> Respuesta Final
# [Fin de la Demo]
