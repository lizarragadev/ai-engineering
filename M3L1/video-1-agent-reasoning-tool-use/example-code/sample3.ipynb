# %%
# Video 1: Razonamiento de Agentes y Uso de Herramientas — De Pipelines de LLM a Agentes

# %%
# Por qué el razonamiento importa

# %%
import time

print("El razonamiento permite a los agentes dividir problemas complejos en pasos más pequeños y lógicos.")
time.sleep(0.6)
print("En lugar de adivinar, el agente obtiene los datos necesarios o realiza cálculos exactos antes de responder.")
time.sleep(1.0)
# Out:
# El razonamiento permite a los agentes dividir problemas complejos en pasos más pequeños y lógicos.
# En lugar de adivinar, el agente obtiene los datos necesarios o realiza cálculos exactos antes de responder.
