# %%
# Tool

# %%
from typing import Callable, Dict

def calculator(expr: str) -> float:
    """
    Calculadora muy simple para fines de demostración.
    NOTA DE SEGURIDAD: Nunca uses eval con entrada no confiable en producción.
    """
    return eval(expr)

TOOLS: Dict[str, Callable] = {
    "calculator": calculator
}
