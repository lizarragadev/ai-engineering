# %%
# Video 1: Razonamiento de Agentes y Uso de Herramientas — De Pipelines de LLM a Agentes

# %%
# Introducción

# %%
import time

print("⏱️ 00:00–00:30 Introducción ===")
print("¡Hola y bienvenido! En esta lección exploraremos los Agentes de IA — el siguiente paso en los sistemas inteligentes.")
time.sleep(0.5)
print("Los pipelines tradicionales de LLM son estáticos: reciben texto, producen una respuesta y se detienen.")
time.sleep(0.6)
print("Los agentes cambian el paradigma cuando necesitamos razonamiento paso a paso, toma de decisiones o datos reales.")
time.sleep(1.0)
# Out:
# ⏱️ 00:00–00:30 Introducción ===
# ¡Hola y bienvenido! En esta lección exploraremos los Agentes de IA — el siguiente paso en los sistemas inteligentes.
# Los pipelines tradicionales de LLM son estáticos: reciben texto, producen una respuesta y se detienen.
# Los agentes cambian el paradigma cuando necesitamos razonamiento paso a paso, toma de decisiones o datos reales.
